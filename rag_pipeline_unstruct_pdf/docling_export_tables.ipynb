# %%
# !pip install docling markdown2 pandas
# Out:
# Requirement already satisfied: docling in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: markdown2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (2.5.3)
# Requirement already satisfied: pandas in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (4.13.4)
# Requirement already satisfied: certifi>=2024.7.4 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2025.4.26)
# Requirement already satisfied: docling-core<3.0.0,>=2.26.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core[chunking]<3.0.0,>=2.26.0->docling) (2.29.0)
# Requirement already satisfied: docling-ibm-models<4.0.0,>=3.4.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (3.4.2)
# Requirement already satisfied: docling-parse<5.0.0,>=4.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (4.0.1)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (0.30.2)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (5.4.0)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2.1.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (3.1.5)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (11.2.1)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2.11.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2.9.1)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2.10)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (4.30.1)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (1.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (4.67.1)
# Requirement already satisfied: typer<0.16.0,>=0.12.5 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling) (0.15.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.13.2)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (4.23.0)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (3.78.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (6.0.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.9.0)
# Requirement already satisfied: semchunk<3.0.0,>=2.2.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core[chunking]<3.0.0,>=2.26.0->docling) (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-core[chunking]<3.0.0,>=2.26.0->docling) (4.51.3)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (4.11.0.86)
# Requirement already satisfied: safetensors<1,>=0.4.3 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from safetensors[torch]<1,>=0.4.3->docling-ibm-models<4.0.0,>=3.4.0->docling) (0.5.3)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (2.7.0)
# Requirement already satisfied: torchvision<1,>=0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (0.22.0)
# Requirement already satisfied: scikit-image in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (0.25.2)
# Requirement already satisfied: python-bidi in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (0.6.6)
# Requirement already satisfied: Shapely in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (2.1.0)
# Requirement already satisfied: pyclipper in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (1.3.0.post6)
# Requirement already satisfied: ninja in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (1.11.1.4)
# Requirement already satisfied: filelock in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from huggingface_hub<1,>=0.23->docling) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from huggingface_hub<1,>=0.23->docling) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from huggingface_hub<1,>=0.23->docling) (24.2)
# Requirement already satisfied: attrs>=19.2.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4.0.0,>=3.4.0->docling) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.26.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.24.0)
# Requirement already satisfied: et-xmlfile in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (1.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from python-pptx<2.0.0,>=1.0.2->docling) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (2.4.0)
# Requirement already satisfied: mpire[dill] in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (2.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.14.0)
# Requirement already satisfied: networkx in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.4.2)
# Requirement already satisfied: jinja2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from triton==3.3.0->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (65.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.21.1)
# Requirement already satisfied: click>=8.0.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from typer<0.16.0,>=0.12.5->docling) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from typer<0.16.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from typer<0.16.0,>=0.12.5->docling) (14.0.0)
# Requirement already satisfied: six>=1.5 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<0.16.0,>=0.12.5->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<0.16.0,>=0.12.5->docling) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.16.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.0.2)
# Requirement already satisfied: multiprocess in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.70.18)
# Requirement already satisfied: dill>=0.4.0 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from multiprocess->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.26.0->docling) (0.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)

# %%
import logging
import time
from pathlib import Path
import pandas as pd
from docling.document_converter import DocumentConverter

_log = logging.getLogger(__name__)

logging.basicConfig(level=logging.INFO)

input_doc_path = Path("./research_docs/TABLAS P-3 Comparativa de Estandares.pdf")
output_dir = Path("scratch")

doc_converter = DocumentConverter()

start_time = time.time()

conv_res = doc_converter.convert(input_doc_path)

output_dir.mkdir(parents=True, exist_ok=True)

doc_filename = conv_res.input.file.stem

# Export tables
for table_ix, table in enumerate(conv_res.document.tables):
    table_df: pd.DataFrame = table.export_to_dataframe()
    print(f"## Table {table_ix}")
    print(table_df.to_markdown())

    # Save the table as csv
    element_csv_filename = output_dir / f"{doc_filename}-table-{table_ix + 1}.csv"
    _log.info(f"Saving CSV table to {element_csv_filename}")
    table_df.to_csv(element_csv_filename)

    # Save the table as html
    element_html_filename = output_dir / f"{doc_filename}-table-{table_ix + 1}.html"
    _log.info(f"Saving HTML table to {element_html_filename}")
    with element_html_filename.open("w") as fp:
        fp.write(table.export_to_html(doc=conv_res.document))

end_time = time.time() - start_time
# Out:
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.document_converter:Initializing pipeline for StandardPdfPipeline with options hash 70041f74270850b7bedf7c8f5c2dcede
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# /home/maudev/develoop/incyte/POCS/multi_modal_rags/.venv/lib/python3.10/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cpu'
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# INFO:easyocr.easyocr:Download complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# INFO:easyocr.easyocr:Download complete.
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cpu'
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cpu'
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered picture descriptions: ['vlm', 'api']
# INFO:docling.pipeline.base_pipeline:Processing document TABLAS P-3 Comparativa de Estandares.pdf
# INFO:docling.document_converter:Finished converting document TABLAS P-3 Comparativa de Estandares.pdf in 253.89 sec.
# INFO:__main__:Saving CSV table to scratch/TABLAS P-3 Comparativa de Estandares-table-1.csv
# INFO:__main__:Saving HTML table to scratch/TABLAS P-3 Comparativa de Estandares-table-1.html
# ## Table 0
# |    | USO DEL EDIFICIO                    | FUENTE DE INFORMACION                  | POBLACION x Dormitorio                                    | %POBLACION servida cada 5'      | LIMITE DE TIEMPO DE ESPERA                        |
# |---:|:------------------------------------|:---------------------------------------|:----------------------------------------------------------|:--------------------------------|:--------------------------------------------------|
# |  0 | VIVIENDA RENTA ELEVADA APARTAMENTOS | Ref. 1 Ref. 2 Thyssen Otis Orona Zener | 1/1.3 p/d 1.3 p/d 1.3 p/d 1/1.3 p/d -- 1.3 p/d            | 6/8 % 7.25 % 7.5 % 7.5 % 6 % -- | 60/70 seg. 50 seg. 40 seg. 60/70 seg. -- 60 seg.  |
# |  1 | VIVIENDA RENTA MEDIA Y VERANIEGA    | Ref. 1 Ref. 2 Thyssen Otis Orona Zener | 1.3/1.5 p/d 3p + 1 p/d 3p + 1 p/d 1.3/1.7 p/d -- 3p+1 p/d | 5/7 % 6 % 7.5 % 7.5 % 6 % --    | 70/80 seg. 75 seg. 40 seg. 80/100 seg. -- 90 seg. |
# |  2 | OFICINAS PROPIEDAD UNICA OFICIALES  | Ref. 1 Ref. 2 Thyssen Otis Orona       | 10/13 m 2 /p 12 m 2 /p -- 10/14 m 2 /p --                 | 15/20 % 17.5 % -- 15/20 % 17%   | 25/30 seg. 30 seg. -- 25/35 seg. 30/35 seg.       |
# |  3 | OFICINAS MULTIPROPIEDAD             | Ref. 1 Ref. 2 Thyssen Otis Orona       | 10/12 m 2 /p 11 m 2 /p -- 9/13 m 2 /p --                  | 12/15 % 13.5 % -- 12/15 % 12 %  | 25/30 seg. 30 seg. -- 25/35 seg. 30/35 seg.       |
# |  4 | HOTELES ***** ****                  | Ref. 1 Ref. 2 Thyssen Otis Orona       | 1.2/1.6 p/hab. 1.4 p/hab. -- 1.2/1.5 p/hab. --            | 10/20 % 14 % -- 15/15 % 12 %    | 35/50 seg. 35 seg. -- 30/40 seg. 30/35 seg.       |
# |  5 | HOTELES *** ** *                    | Ref. 1 Ref. 2 Thyssen Otis Orona       | 1.2/1.6 p/hab. 1.7 p/hab. -- 1.5/2 p/hab. --              | 8/15 % 11 % -- 10/12 % 12 %     | 40/60 % 50 % -- 40/60 % 35-40 %                   |
